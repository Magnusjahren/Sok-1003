# %% [markdown]
# # Mappeoppgave 1
# ## <u>Beskrivelse
# Les oppgaveteksten nøye. Se hvordan man leverer oppgaven <th><a href='https://uit-sok-1003-h22.github.io/semesteroppgave.html'>her</a> </th> og  <th><a href='https://uit-sok-1003-h22.github.io/github.html'>her</a>. Husk at den skal leveres både som jupyter-fil og som PDF. Kommenter kodene du skriver i alle oppgaver og vær nøye på å definere aksene mm i figurer. I noen av oppgavetekstene står det hint, men det betyr ikke at de ikke kan løses på andre måter
#
# ##### For å hente denne filen til Jupyter gjør du slik:
#
# <ol>
# <li>Åpne et "terminalvindu"
# <li>Gå til hjemmeområdet ditt
#
#
#     [user@jupty02 ~]$ cd
# <li>Lag en ny mappe på ditt hjemmeområde ved å skrive inn i terminalvinduet
#
#     [user@jupty02 ~]$ mkdir SOK-1003-eksamen-2022-mappe1
#
# <li>Gå så inn i den mappen du har laget ved å skrive
#
#     [user@jupty02 ~]$ cd SOK-1003-eksamen-2022-mappe1
# <li> Last ned kursmateriellet ved å kopiere inn følgende kommando i kommandovinduet:
#
#     [user@jupty02 sok-1003]$ git clone https://github.com/uit-sok-1003-h22/mappe/
# </ol>
# <br> Oppgi gruppenavn m/ medlemmer på epost o.k.aars@uit.no innen 7/10, så blir dere satt opp til tidspunkt for presentasjon 19/10.
# <br>Bruk så denne filen til å gjøre besvarelsen din. Ved behov; legg til flere celler ved å trykke "b"
# </br>
# <hr>

# %% [markdown]
# ## <u> Oppgavene
#
# ### Oppgave 1 (5 poeng)
# a) Lag en kort fortelling i en python kode som inkluderer alle de fire typer variabler vi har lært om i kurset. Koden skal kunne kjøres med print(). Koden burde inneholde utregninger av elementer du har definert

# %%
vekt = 90 #legger inn int
høyde = 1.83 #Float
navn = "Petter" #String#
bmi = vekt / (høyde * høyde) #Regning for å finne bmi


print(navn, "Lurer på sin bmi og finner ut at den er", bmi) # Printer beskjeden med navn og bmi


if bmi > 25 :
    print("Petter er overvektig") # If gjør at dersom bmien til Petter er over 25, printer den "Petter er overvektig"
# Out:
# Petter Lurer på sin bmi og finner ut at den er 26.874496103198062
# Petter er overvektig

# %% [markdown]
# ### Oppgave 2 (10 poeng)

# %% [markdown]
# Leieprisene i landet har steget de siste månedene. Ved å bruke realistiske tall<br>
# a) Lag tilbuds og etterspørselsfunksjoner for leie av bolig (Bruk av ikke-lineære funksjoner belønnes). <br>
#  <br> Definer funksjonene slik at det er mulig å finne en likevekt

# %%
from matplotlib import pyplot as plt
import numpy as np



def etterspørsel(x):
    return x**2
etterspørsel(100)
def tilbud(x):
    return (x-200)**2
tilbud(10000)
# Setter opp funksjonen for tilbud og etterspørsel
# Out:
# 96040000

# %%
q = np.linspace(1,200)


q = np.linspace(0,200)
fig,ax=plt.subplots()
ax.set_ylabel('Pris')
ax.set_xlabel('Antall leieligheter')




ax.plot(q,tilbud(q),label='Tilbud')


ax.plot(q,etterspørsel(q),color='green',label='Etterspørsel')

#adding legend:
ax.legend(loc='upper center',frameon=False)

#Vi lager en graf for tilbud og etterspørsel og finner at likevekten ligger på 10000kr og 100 leilighter

# %% [markdown]
# b) Vis at disse er henholdvis fallende og stigende, ved bruk av
# - Regning
# - figurativt (matplotlib)
# Husk å markere aksene tydelig og at funskjonene er definert slik at linjene krysser

# %% [markdown]
# c) Kommenter funksjonene og likevekten. Vis gjerne figurativt hvor likevekten er ved bruk av scatter

# %%
#Når etterspørselen øker, så øker prisen også. Når tilbudet er lavt så synker prisen på leieligheter. Likevekten finner vi på pris 10000 
#og antall leieligheter 100.

pris = [2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000]
Leieligheter = [20, 40, 60, 80, 100, 120, 140, 160]
plt.scatter(Leieligheter, pris)
plt.show()

# %% [markdown]
# ### Oppgave 3 (15 poeng)

# %% [markdown]
# SSB har omfattende data på befolkningsutvikling (https://www.ssb.no/statbank/table/05803/tableViewLayout1/). Disse dataene skal du bruke i de neste deloppgavene.
#
# a) lag lister av følgende variabler: "Befolkning 1. januar", "Døde i alt", "Innflyttinger" og "Utflyttinger". Velg selv variabelnavn når du definerer dem i python. Første element i hver liste skal være variabelnavnet. Bruk tall for perioden 2012-2021. Lag så en liste av disse listene. Du kan kalle den "ssb".
# <br><br>
# <b>Hint:</b> når du skal velge variabler på SSB sin nettside må du holde inne ctrl for å velge flere variabler.

# %%
import numpy as np
År = ["År",2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
Befolkning = ["Befolkning",4985870, 5051275, 5109056, 5165802, 5213985, 5258317, 5295619, 5328212, 5367580, 5391369]
Døde = ["Døde",41992, 41282, 40394, 40727, 40276, 40774, 40840, 40684, 40611, 42002]
Innflyttninger = ["Innflttninger",78570, 75789, 70030, 67276, 66800, 58192, 52485, 52153, 38071, 53947]
Utflyttninger = ["Utflyttninger",31227, 35716, 31875, 37474, 40724, 36843, 34382, 26826, 26744, 34297]

ssb = [År, Befolkning, Døde, Innflyttninger, Utflyttninger]
print(ssb)
# Vi lager liste for år,befolkning,døde, innflytninger og utflytninger
# Out:
# [['År', 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021], ['Befolkning', 4985870, 5051275, 5109056, 5165802, 5213985, 5258317, 5295619, 5328212, 5367580, 5391369], ['Døde', 41992, 41282, 40394, 40727, 40276, 40774, 40840, 40684, 40611, 42002], ['Innflttninger', 78570, 75789, 70030, 67276, 66800, 58192, 52485, 52153, 38071, 53947], ['Utflyttninger', 31227, 35716, 31875, 37474, 40724, 36843, 34382, 26826, 26744, 34297]]

# %% [markdown]
# b) konverter "ssb" til en numpy matrise og gi den et nytt navn

# %%
import numpy as np
ssb_n = np.array(ssb)
print(ssb_n)
# Out:
# [['År' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019' '2020'
#   '2021']
#  ['Befolkning' '4985870' '5051275' '5109056' '5165802' '5213985'
#   '5258317' '5295619' '5328212' '5367580' '5391369']
#  ['Døde' '41992' '41282' '40394' '40727' '40276' '40774' '40840' '40684'
#   '40611' '42002']
#  ['Innflttninger' '78570' '75789' '70030' '67276' '66800' '58192' '52485'
#   '52153' '38071' '53947']
#  ['Utflyttninger' '31227' '35716' '31875' '37474' '40724' '36843' '34382'
#   '26826' '26744' '34297']]

# %% [markdown]
# c) Putt alle tallene inn i en egen matrise og konverter disse til int

# %%
ssb_int = ssb_n[:,1:]
ssb_int = np.array(ssb_int[:],dtype=int)
print(ssb_int)
# Vi tar bort første kolonne
# Out:
# [[   2012    2013    2014    2015    2016    2017    2018    2019    2020
#      2021]
#  [4985870 5051275 5109056 5165802 5213985 5258317 5295619 5328212 5367580
#   5391369]
#  [  41992   41282   40394   40727   40276   40774   40840   40684   40611
#     42002]
#  [  78570   75789   70030   67276   66800   58192   52485   52153   38071
#     53947]
#  [  31227   35716   31875   37474   40724   36843   34382   26826   26744
#     34297]]

# %% [markdown]
# d) vis befolkningsutviklingen grafisk for de gjeldene årene ved bruk av matplotlib, og mer spesifikt "fig, ax = plt.subplots()". Vis befolkning på y-aksen i millioner

# %%
from matplotlib import pyplot as plt

fig,ax=plt.subplots()
ax.set_ylabel('Millioner')
ax.set_xlabel('År')
ax.scatter(ssb_int[0,:][:],ssb_int[1,:][:])


# Lager en graf med millioner innbygger på y aksen og med årstall på x aksen for å vise utviklingen i befolkningstall

# %% [markdown]
# e) Lag det samme plottet ved bruk av oppslag. Hva er fordelen med dette?

# %%
from matplotlib import pyplot as plt

plot={"År":ssb_int[0,:], "Befolkning":ssb_int[1,:]}
print(type(plot))

fig,ax=plt.subplots()
ax.set_ylabel('Millioner')
ax.set_xlabel('År')
ax.scatter(ssb_int[0,:],ssb_int[1,:])


#Fordelen med å bruke omslag er at koden blir lettere å lese og du slipper å ha med datasettet.
# Out:
# <class 'dict'>

# %% [markdown]
# f) Hva er den relative befolkningstilveksten utenom fødsler (dvs. innvandring/utvandring)? Definer en ny array og legg den til i oppslaget du laget i oppgaven tidligere. Kall den "rel_immigration". Plot denne sammen med grafen du laget i (d).

# %%
import numpy as np
from matplotlib import pyplot as plt

innflyttninger = ssb_int[-2] #henter ut innflyttninger fra ssb listen
utflyttninger = ssb_int[-1]  #henter ut utflyttninger fra ssb listen
rel_immigration = np.subtract(innflyttninger,utflyttninger) #bruker np subtract for å finne rel immigration
Befolkning2 = np.subtract(ssb_int[1], rel_immigration) # lager befolkning2
plot_2={"År":ssb_int[0], "Befolkning":ssb_int[1][:], "rel_immigration":rel_immigration[:], "Befolkning uten fødseler":Befolkning2}

fig,ax=plt.subplots()
ax.set_ylabel('Befolkning')
ax.set_xlabel('År')
ax.scatter(plot_2["År"], plot_2["Befolkning uten fødseler"])
ax.scatter(plot_2["År"], plot_2["Befolkning"])

# %% [markdown]
# g) ekstrapoeng. Kan plotte de samme tallene (dvs "rel_immigration" og "befolkning" sammen med år) i to figurer ved siden av hverandre ved bruk av "fig, (ax1, ax2) = plt.subplots(1, 2)". Gi grafene ulik farge

# %%
fig,(ax1,ax2) = plt.subplots(1,2)
ax1.plot(plot_2["År"], plot_2["Befolkning"], label = Befolkning, color = "Green")
ax2.plot(plot_2["År"], plot_2["Befolkning uten fødseler"], label = Befolkning2, color = "Blue")

#figuren til venstre viser total befolkning
#fiugren til høyre viser befolkning minus innvandring/utvandring

# %% [markdown]
# ## Oppgave 4 (20 poeng)

# %% [markdown]
# Et lån består som regel av et månedlig terminbeløp. Dette beløpet er summen av avdrag (nedbetalingen på lånet) og renter. Vi antar månedlig forrenting i alle oppgavene. Dvs. at det er 12 terminer i hvert år.<br><br>
# a) Lag en funksjon som regner ut hvor mye lånet "x" koster deg i renteutgifter for "t" terminer med årlig rente "r" for et serielån. <br> <br>  Siden dette er et serielån, så vil avdragene være like hver måned men renteutgiftene reduseres i takt med avdragene. Renteutgiftene for en gitt termin "t" vil derfor være den årlige renten "r" (delt på antall forrentinger "f") på gjenværende beløp på det tidspunktet.   $renteutgifter_{t} = (x-a*t)*{r/f}$   <br>  <br>
# Siden vi er ute etter den totale kostnaden i svaret, må du summere renteutgiftene over alle terminer, det vil si $\sum_{t=1}^N(x-a*t)*{r/f}$
#
#
# <br>
# <b>Hint:</b> siden terminbeløpet varierer for hver måned (pga at rentene endres), må alle enkeltperioder summeres. Det kan være nyttige å bruke funksjonen np.arange() til dette.

# %%
import numpy as np


def serielån(x,a,t,r,f):
    return (x-a*(t-1))*r/f


#definisjon serielån
# Out:
# 153750.0

# %% [markdown]
# b) regn ut hvor mye lånet koster deg med henholdsvis 10, 20 og 30 års tilbakebetaling. Anta 1 000 000 kr lånebeløp med 3% rente

# %%
Avdrag = 1000000/120
Lånesum = 1000000
Rente = 0.03
Fe = 12
Termin = np.arange(0,120) # bruker arange funksjonen for å lage en array for hver av terminene
ti_år = serielån(Lånesum,Avdrag,Termin,Rente,Fe)

np.sum(ti_år)
print(np.sum(ti_år))



Avdrag20 = 1000000/240
Termin20 = np.arange(0,240)

tjue_år = serielån(Lånesum,Avdrag20,Termin20,Rente,Fe)
np.sum(tjue_år)
print(np.sum(tjue_år))

Avdrag30 = 1000000/360
Termin30 = np.arange(0,360)

tretti_år = serielån(Lånesum,Avdrag30,Termin30,Rente,Fe)
np.sum(tretti_år)
#bruker formelen fra oppgave a for å regne ut renteutgiftene for 10,20 og 30 år
# Out:
# 153750.0
# 303750.0
# 453750.0

# %% [markdown]
# c) Vis hva det samme lånet koster som annuitetslån, dvs differansen mellom alle terminbeløp og lånebeløp.<br> <br> Annuitetslån gir like terminbeløp hver måned, men renten utgjør en større del av dette beløpet i starten. Terminbeløpet for et annuitetslån er definert ved formelen:
# $T = x*\frac{r/f} {(1-(1+(r/f))^{-t})}$, hvor x=lånebeløp, r = årlig rente, t = terminer, f= antall forrentinger

# %%
Lånesum_a = 1000000
Termin_a = 120



def Annu(x,r,f,t):
    return x *(r/f)/(1-(1+(r/f))**-t)
ti_år_a = Annu(Lånesum_a,Rente,Fe,Termin_a)  

ti_år_lån_sum = ti_år_a * 120
 
print(ti_år_lån_sum- 1000000)         

#bruker formelen for finne terminbeløpet, deretter gange med antall terminer for å finne total kostnad. minus 1 million for å finne differansen
# Out:
# 158728.93638069555

# %% [markdown]
# c) Vis hvordan utviklingen i rentekostnader og avdrag på terminer for serielån grafisk ved hjelp av stackplot funksjonen i matplotlib. Anta et bankinnskudd x = 1 000 000 kr, årlig rente r=3% og antall terminer t = 240 (det vil si 2 år). Siden vi må vise utviklingen per termin, husk at "t" også definerer hvilken måned vi er i. Dvs, hvis t=15, har det gått 1 år og 3 mnd med terminer. Se forøvrig relevante formler i oppgave (a)
#
# <br>
#
# <b>Hint1:</b> Siden avdragene er like for alle måneder, kan det være lurt å definere det månedlige avdraget som en liste og gange det med antall perioder. </br>
# <b>Hint2:</b> Siden vi er ute etter både rentekostnader og avdrag hver for seg, kan det være lurt å definere en funksjon for hver av dem. </br>

# %%
Avdrag_20 = 1000000/240
liste_avdrag20 = [Avdrag_20] 

liste_avdrag20_ = liste_avdrag20 * 240 #lager en liste med faste avdrag for 240 måneder.

tjue_år = serielån(Lånesum,Avdrag20,Termin20,Rente,Fe) #bruker formelen fra tidligere for å få rentekostnader for hver måned i 240 måneder.

Terminer = np.arange(0,240)
fig, ax = plt.subplots()
ax.stackplot(Terminer, liste_avdrag20_, tjue_år)
ax.set_ylabel("Månedsbeløp")
ax.set_xlabel("Måneder")

#ax.stackplot funskjonen for å vise nedgangen av rentekostnadene i et serielån
#oransj er renktekostnader og blå er faste avdrag
# Out:
# Text(0.5, 0, 'Måneder')
